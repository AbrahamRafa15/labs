# %% [markdown]
# # Setup

# %%
NEO4J_START_FROM_SCRATCH = True

# NEO4J_WORKDIR = "/var/lib/neo4j"
NEO4J_PORT = 7687
NEO4J_WEBUI_PORT = 7474

NEO4J_INIT_USER = "neo4j"
NEO4J_INIT_PASSWORD = "password"

# %%
import os
from pathlib import Path

LOCALHOST_WORKDIR = f"{os.path.join(os.path.relpath(Path.cwd()))}"
DOCKER_MOUNTDIR = os.path.join(LOCALHOST_WORKDIR, "mount")

mount_path = Path(DOCKER_MOUNTDIR)
mount_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Stop neo4j.docker-compose.yml

# %%
# !docker compose -f neo4j.docker-compose.yml down -v
# Out:
# open /Users/abrahammartinezceron/Documents/NoSQL/labs/neo4j/neo4j.docker-compose.yml: no such file or directory

# %%
import shutil

if NEO4J_START_FROM_SCRATCH:
    shutil.rmtree(DOCKER_MOUNTDIR)
    Path(DOCKER_MOUNTDIR).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Start neo4j.docker-compose.yml

# %%
import os
import yaml
from IPython.display import Markdown, display

neo4j_compose_dict = {
    "name": "neo4j-compose",
    "services": {
        "neo4j": {
            "image": "neo4j:ubi9",
            "container_name": "neo4j-instance",
            "volumes": [
                f"{os.path.join(DOCKER_MOUNTDIR,"data")}:/data",
                f"{os.path.join(DOCKER_MOUNTDIR,"neo4j","logs")}:/logs",
                f"{os.path.join(DOCKER_MOUNTDIR,"neo4j","import")}:/var/lib/neo4j/import",
                f"{os.path.join(DOCKER_MOUNTDIR,"plugins")}:/plugins",
            ],
            "environment": {
                "NEO4J_AUTH": f"{NEO4J_INIT_USER}/{NEO4J_INIT_PASSWORD}",
                # NEO4J 5.x Memory Settings (Double underscores represent single underscores in .conf)
                "NEO4J_server_memory_heap_initial__size": "512m",
                "NEO4J_server_memory_heap_max__size": "1G",
                "NEO4J_server_memory_pagecache_size": "512m",
                "NEO4J_dbms_memory_heap_initial_size": "1024m",
                "NEO4J_dbms_memory_heap_max_size": "2G",
                # Plugin Configuration
                "NEO4J_PLUGINS": '["apoc", "graph-data-science"]',
                # Security: Allow APOC, GDS to run procedures
                "NEO4J_dbms_security_procedures_unrestricted": "apoc.*,gds.*",
                "NEO4J_dbms_security_procedures_allowlist": "apoc.*,gds.*",
                "NEO4J_server_config_strict__validation_enabled": "false",
                "NEO4J_server_bolt_enabled": "true",
            },
            "ports": [
                f"{NEO4J_WEBUI_PORT}:{NEO4J_WEBUI_PORT}",
                f"{NEO4J_PORT}:{NEO4J_PORT}",
            ],
            "restart": "unless-stopped",
            "deploy": {"resources": {"limits": {"cpus": "2.0", "memory": "2048M"}}},
        }
    },
}

neo4j_compose_yaml_path = os.path.join(LOCALHOST_WORKDIR, "neo4j.docker-compose.yml")
neo4j_compose_yaml_contents = yaml.dump(
    neo4j_compose_dict, default_flow_style=False, sort_keys=False, indent=4
)
with open(neo4j_compose_yaml_path, "w") as f:
    f.write(neo4j_compose_yaml_contents)

print(f"Successfully created: '{os.path.relpath(neo4j_compose_yaml_path)}'")
display(Markdown(f"```yaml\n{neo4j_compose_yaml_contents}\n```"))
# Out:
# Successfully created: 'neo4j.docker-compose.yml'
# ```yaml
# name: neo4j-compose
# services:
#     neo4j:
#         image: neo4j:ubi9
#         container_name: neo4j-instance
#         volumes:
#         - ./mount/data:/data
#         - ./mount/neo4j/logs:/logs
#         - ./mount/neo4j/import:/var/lib/neo4j/import
#         - ./mount/plugins:/plugins
#         environment:
#             NEO4J_AUTH: neo4j/password
#             NEO4J_server_memory_heap_initial__size: 512m
#             NEO4J_server_memory_heap_max__size: 1G
#             NEO4J_server_memory_pagecache_size: 512m
#             NEO4J_dbms_memory_heap_initial_size: 1024m
#             NEO4J_dbms_memory_heap_max_size: 2G
#             NEO4J_PLUGINS: '["apoc", "graph-data-science"]'
#             NEO4J_dbms_security_procedures_unrestricted: apoc.*,gds.*
#             NEO4J_dbms_security_procedures_allowlist: apoc.*,gds.*
#             NEO4J_server_config_strict__validation_enabled: 'false'
#             NEO4J_server_bolt_enabled: 'true'
#         ports:
#         - 7474:7474
#         - 7687:7687
#         restart: unless-stopped
#         deploy:
#             resources:
#                 limits:
#                     cpus: '2.0'
#                     memory: 2048M
#
# ```

# %%
# !docker compose -f neo4j.docker-compose.yml up -d --wait
# Out:
# [+] up 0/1
#  ⠋ Image neo4j:ubi9 Pulling                                                0.1s
# [+] up 0/1
#  ⠙ Image neo4j:ubi9 Pulling                                                0.2s
# [+] up 0/1
#  ⠹ Image neo4j:ubi9 Pulling                                                0.3s
# [+] up 0/1
#  ⠸ Image neo4j:ubi9 Pulling                                                0.4s
# [+] up 0/1
#  ⠼ Image neo4j:ubi9 Pulling                                                0.5s
# [+] up 0/1
#  ⠴ Image neo4j:ubi9 Pulling                                                0.6s
# [+] up 0/1
#  ⠦ Image neo4j:ubi9 Pulling                                                0.7s
# [+] up 0/1
#  ⠧ Image neo4j:ubi9 Pulling                                                0.8s
# [+] up 0/1
#  ⠇ Image neo4j:ubi9 Pulling                                                0.9s
# [+] up 0/1
#  ⠏ Image neo4j:ubi9 Pulling                                                1.0s
# [+] up 0/1
#  ⠋ Image neo4j:ubi9 Pulling                                                1.1s
# [+] up 0/1
#  ⠙ Image neo4j:ubi9 Pulling                                                1.2s
# [+] up 0/1
#  ⠹ Image neo4j:ubi9 Pulling                                                1.3s
# [+] up 0/1
#  ⠸ Image neo4j:ubi9 Pulling                                                1.4s
# [+] up 0/1
#  ⠼ Image neo4j:ubi9 Pulling                                                1.5s
# [+] up 0/1
#  ⠴ Image neo4j:ubi9 Pulling                                                1.6s
# [+] up 0/1
#  ⠦ Image neo4j:ubi9 Pulling                                                1.7s
# [+] up 0/1
#  ⠧ Image neo4j:ubi9 Pulling                                                1.8s
# [+] up 0/1
#  ⠇ Image neo4j:ubi9 Pulling                                                1.9s
# [+] up 0/1
#  ⠏ Image neo4j:ubi9 Pulling                                                2.0s
# [+] up 0/1
#  ⠋ Image neo4j:ubi9 Pulling                                                2.1s
# [+] up 0/1
#  ⠙ Image neo4j:ubi9 Pulling                                                2.2s
# [+] up 0/1
#  ⠹ Image neo4j:ubi9 Pulling                                                2.3s
# [+] up 0/1
#  ⠸ Image neo4j:ubi9 Pulling                                                2.4s
# [+] up 0/1
#  ⠼ Image neo4j:ubi9 Pulling                                                2.5s
# [+] up 0/1
#  ⠴ Image neo4j:ubi9 Pulling                                                2.6s
# [+] up 0/1
#  ⠦ Image neo4j:ubi9 Pulling                                                2.7s
# [+] up 0/1
#  ⠧ Image neo4j:ubi9 Pulling                                                2.8s
# [+] up 0/1
#  ⠇ Image neo4j:ubi9 Pulling                                                2.9s
# [+] up 0/1
#  ⠏ Image neo4j:ubi9 Pulling                                                3.0s
# [+] up 0/1
#  ⠋ Image neo4j:ubi9 Pulling                                                3.1s
# [+] up 0/1
#  ⠙ Image neo4j:ubi9 Pulling                                                3.2s
# [+] up 0/1
#  ⠹ Image neo4j:ubi9 Pulling                                                3.3s
# [+] up 0/1
#  ⠸ Image neo4j:ubi9 Pulling                                                3.4s
# [+] up 0/1
#  ⠼ Image neo4j:ubi9 Pulling                                                3.5s
# [+] up 0/1
#  ⠴ Image neo4j:ubi9 Pulling                                                3.6s
# [+] up 0/1
#  ⠦ Image neo4j:ubi9 Pulling                                                3.7s
# [+] up 0/1
#  ⠧ Image neo4j:ubi9 Pulling                                                3.8s
# [+] up 0/1
#  ⠇ Image neo4j:ubi9 Pulling                                                3.9s
# [+] up 0/1
#  ⠏ Image neo4j:ubi9 Pulling                                                4.0s
# [+] up 0/1
#  ⠋ Image neo4j:ubi9 Pulling                                                4.1s
# [+] up 0/1
#  ⠙ Image neo4j:ubi9 Pulling                                                4.2s
# [+] up 0/1
#  ⠹ Image neo4j:ubi9 Pulling                                                4.3s
# [+] up 0/1
#  ⠸ Image neo4j:ubi9 Pulling                                                4.4s
# [+] up 0/1
#  ⠼ Image neo4j:ubi9 Pulling                                                4.5s
# [+] up 0/1
#  ⠴ Image neo4j:ubi9 Pulling                                                4.6s
# [+] up 0/1
#  ⠦ Image neo4j:ubi9 Pulling                                                4.7s
# [+] up 0/1
#  ⠧ Image neo4j:ubi9 Pulling                                                4.8s
# [+] up 0/1
#  ⠇ Image neo4j:ubi9 Pulling                                                4.9s
# [+] up 0/1
#  ⠏ Image neo4j:ubi9 Pulling                                                5.0s
# [+] up 0/1
#  ⠋ Image neo4j:ubi9 Pulling                                                5.1s
# [+] up 0/1
#  ⠙ Image neo4j:ubi9 Pulling                                                5.2s
# [+] up 0/1
#  ⠹ Image neo4j:ubi9 Pulling                                                5.3s
# [+] up 0/1
#  ⠸ Image neo4j:ubi9 Pulling                                                5.4s
# [+] up 0/1
#  ⠼ Image neo4j:ubi9 Pulling                                                5.5s
# [+] up 0/6
#  ⠴ Image neo4j:ubi9 [⠀⠀⠀⠀⠀] Pulling                                        5.6s
# [+] up 1/6
#  ⠦ Image neo4j:ubi9 [⣿⠀⠀⠀⠀] Pulling                                        5.7s
# [+] up 1/6
#  ⠧ Image neo4j:ubi9 [⣿⠀⠀⠀⠀] Pulling                                        5.8s
# [+] up 1/6
#  ⠇ Image neo4j:ubi9 [⣿⠀⠀⠀⠀] Pulling                                        5.9s
# [+] up 2/7
#  ⠏ Image neo4j:ubi9 [⣿⠀⠀⠀⠀⣿] Pulling                                       6.0s
# [+] up 3/7
#  ⠋ Image neo4j:ubi9 [⣿⠀⣿⠀⠀⣿] Pulling                                       6.1s
# [+] up 3/7
#  ⠙ Image neo4j:ubi9 [⣿⠀⣿⠀⠀⣿] Pulling                                       6.2s
# [+] up 3/7
#  ⠹ Image neo4j:ubi9 [⣿⠀⣿⠀⠀⣿] Pulling                                       6.3s
# [+] up 3/7
#  ⠸ Image neo4j:ubi9 [⣿⠀⣿⠀⠀⣿] Pulling                                       6.4s
# [+] up 3/7
#  ⠼ Image neo4j:ubi9 [⣿⠀⣿⠀⠀⣿] Pulling                                       6.5s
# [+] up 3/7
#  ⠴ Image neo4j:ubi9 [⣿⠀⣿⠀⠀⣿] Pulling                                       6.6s
# [+] up 3/8
#  ⠦ Image neo4j:ubi9 [⣿⡀⣿⠀⠀⣿⣀] 17.83MB / 375.7MB Pulling                    6.7s
# [+] up 3/8
#  ⠧ Image neo4j:ubi9 [⣿⡀⣿⠀⠀⣿⣀] 18.87MB / 375.7MB Pulling                    6.8s
# [+] up 3/8
#  ⠇ Image neo4j:ubi9 [⣿⡀⣿⠀⠀⣿⣀] 23.07MB / 375.7MB Pulling                    6.9s
# [+] up 3/8
#  ⠏ Image neo4j:ubi9 [⣿⡀⣿⠀⠀⣿⣀] 25.17MB / 375.7MB Pulling                    7.0s
# [+] up 3/8
#  ⠋ Image neo4j:ubi9 [⣿⡀⣿⠀⠀⣿⣤] 28.31MB / 375.7MB Pulling                    7.1s
# [+] up 3/8
#  ⠙ Image neo4j:ubi9 [⣿⡀⣿⠀⠀⣿⣤] 28.31MB / 375.7MB Pulling                    7.2s
# [+] up 3/8
#  ⠹ Image neo4j:ubi9 [⣿⡀⣿⡀⠀⣿⣤] 30.41MB / 375.7MB Pulling                    7.3s
# [+] up 3/8
#  ⠸ Image neo4j:ubi9 [⣿⡀⣿⡀⠀⣿⣶] 33.55MB / 375.7MB Pulling                    7.4s
# [+] up 3/8
#  ⠼ Image neo4j:ubi9 [⣿⡀⣿⡀⠀⣿⣶] 35.65MB / 375.7MB Pulling                    7.5s
# [+] up 4/8
#  ⠴ Image neo4j:ubi9 [⣿⣀⣿⡀⠀⣿⣿] 37.75MB / 375.7MB Pulling                    7.6s
# [+] up 4/8
#  ⠦ Image neo4j:ubi9 [⣿⣀⣿⡀⠀⣿⣿] 40.89MB / 375.7MB Pulling                    7.7s
# [+] up 4/8
#  ⠧ Image neo4j:ubi9 [⣿⣀⣿⡀⠀⣿⣿] 40.89MB / 375.7MB Pulling                    7.8s
# [+] up 4/8
#  ⠇ Image neo4j:ubi9 [⣿⣀⣿⡀⠀⣿⣿] 45.09MB / 375.7MB Pulling                    7.9s
# [+] up 4/8
#  ⠏ Image neo4j:ubi9 [⣿⣀⣿⡀⠀⣿⣿] 47.19MB / 375.7MB Pulling                    8.0s
# [+] up 4/8
#  ⠋ Image neo4j:ubi9 [⣿⣀⣿⡀⠀⣿⣿] 49.28MB / 375.7MB Pulling                    8.1s
# [+] up 4/8
#  ⠙ Image neo4j:ubi9 [⣿⣀⣿⣀⠀⣿⣿] 51.38MB / 375.7MB Pulling                    8.2s
# [+] up 4/8
#  ⠹ Image neo4j:ubi9 [⣿⣀⣿⣀⠀⣿⣿] 53.48MB / 375.7MB Pulling                    8.3s
# [+] up 4/8
#  ⠸ Image neo4j:ubi9 [⣿⣀⣿⣀⠀⣿⣿] 55.57MB / 375.7MB Pulling                    8.4s
# [+] up 4/8
#  ⠼ Image neo4j:ubi9 [⣿⣄⣿⣀⠀⣿⣿] 57.67MB / 375.7MB Pulling                    8.5s
# [+] up 4/8
#  ⠴ Image neo4j:ubi9 [⣿⣄⣿⣀⠀⣿⣿] 59.77MB / 375.7MB Pulling                    8.6s
# [+] up 4/8
#  ⠦ Image neo4j:ubi9 [⣿⣄⣿⣀⠀⣿⣿] 62.91MB / 375.7MB Pulling                    8.7s
# [+] up 4/8
#  ⠧ Image neo4j:ubi9 [⣿⣄⣿⣄⠀⣿⣿] 65.01MB / 375.7MB Pulling                    8.8s
# [+] up 4/8
#  ⠇ Image neo4j:ubi9 [⣿⣄⣿⣄⠀⣿⣿] 67.11MB / 375.7MB Pulling                    8.9s
# [+] up 4/8
#  ⠏ Image neo4j:ubi9 [⣿⣄⣿⣄⠀⣿⣿] 70.25MB / 375.7MB Pulling                    9.0s
# [+] up 4/8
#  ⠋ Image neo4j:ubi9 [⣿⣄⣿⣄⠀⣿⣿] 72.35MB / 375.7MB Pulling                    9.1s
# [+] up 4/8
#  ⠙ Image neo4j:ubi9 [⣿⣄⣿⣄⠀⣿⣿]  75.5MB / 375.7MB Pulling                    9.2s
# [+] up 4/8
#  ⠹ Image neo4j:ubi9 [⣿⣄⣿⣄⠀⣿⣿] 76.55MB / 375.7MB Pulling                    9.3s
# [+] up 4/8
#  ⠸ Image neo4j:ubi9 [⣿⣤⣿⣄⠀⣿⣿] 79.69MB / 375.7MB Pulling                    9.4s
# [+] up 4/8
#  ⠼ Image neo4j:ubi9 [⣿⣤⣿⣄⠀⣿⣿] 81.79MB / 375.7MB Pulling                    9.5s
# [+] up 4/8
#  ⠴ Image neo4j:ubi9 [⣿⣤⣿⣤⠀⣿⣿] 83.89MB / 375.7MB Pulling                    9.6s
# [+] up 4/8
#  ⠦ Image neo4j:ubi9 [⣿⣤⣿⣤⠀⣿⣿] 85.98MB / 375.7MB Pulling                    9.7s
# [+] up 4/8
#  ⠧ Image neo4j:ubi9 [⣿⣤⣿⣤⠀⣿⣿] 88.08MB / 375.7MB Pulling                    9.8s
# [+] up 4/8
#  ⠇ Image neo4j:ubi9 [⣿⣤⣿⣤⠀⣿⣿] 91.23MB / 375.7MB Pulling                    9.9s
# [+] up 4/8
#  ⠏ Image neo4j:ubi9 [⣿⣤⣿⣤⠀⣿⣿] 92.27MB / 375.7MB Pulling                   10.0s
# [+] up 4/8
#  ⠋ Image neo4j:ubi9 [⣿⣤⣿⣤⠀⣿⣿] 95.42MB / 375.7MB Pulling                   10.1s
# [+] up 4/8
#  ⠙ Image neo4j:ubi9 [⣿⣤⣿⣦⠀⣿⣿] 98.57MB / 375.7MB Pulling                   10.2s
# [+] up 4/8
#  ⠹ Image neo4j:ubi9 [⣿⣤⣿⣦⠀⣿⣿] 101.7MB / 375.7MB Pulling                   10.3s
# [+] up 4/8
#  ⠸ Image neo4j:ubi9 [⣿⣤⣿⣦⠀⣿⣿] 101.7MB / 375.7MB Pulling                   10.4s
# [+] up 4/8
#  ⠼ Image neo4j:ubi9 [⣿⣦⣿⣦⠀⣿⣿] 105.9MB / 375.7MB Pulling                   10.5s
# [+] up 4/8
#  ⠴ Image neo4j:ubi9 [⣿⣦⣿⣦⠀⣿⣿]   108MB / 375.7MB Pulling                   10.6s
# [+] up 4/8
#  ⠦ Image neo4j:ubi9 [⣿⣦⣿⣦⠀⣿⣿] 111.1MB / 375.7MB Pulling                   10.7s
# [+] up 4/8
#  ⠧ Image neo4j:ubi9 [⣿⣦⣿⣦⠀⣿⣿] 112.2MB / 375.7MB Pulling                   10.8s
# [+] up 4/8
#  ⠇ Image neo4j:ubi9 [⣿⣦⣿⣶⠀⣿⣿] 115.3MB / 375.7MB Pulling                   10.9s
# [+] up 4/8
#  ⠏ Image neo4j:ubi9 [⣿⣦⣿⣶⠀⣿⣿] 118.5MB / 375.7MB Pulling                   11.0s
# [+] up 4/8
#  ⠋ Image neo4j:ubi9 [⣿⣦⣿⣶⠀⣿⣿] 119.5MB / 375.7MB Pulling                   11.1s
# [+] up 4/8
#  ⠙ Image neo4j:ubi9 [⣿⣦⣿⣶⠀⣿⣿] 121.6MB / 375.7MB Pulling                   11.2s
# [+] up 4/8
#  ⠹ Image neo4j:ubi9 [⣿⣦⣿⣶⠀⣿⣿] 124.8MB / 375.7MB Pulling                   11.3s
# [+] up 4/8
#  ⠸ Image neo4j:ubi9 [⣿⣦⣿⣷⠀⣿⣿] 127.9MB / 375.7MB Pulling                   11.4s
# [+] up 4/8
#  ⠼ Image neo4j:ubi9 [⣿⣦⣿⣷⠀⣿⣿] 127.9MB / 375.7MB Pulling                   11.5s
# [+] up 4/8
#  ⠴ Image neo4j:ubi9 [⣿⣶⣿⣷⠀⣿⣿] 132.1MB / 375.7MB Pulling                   11.6s
# [+] up 4/8
#  ⠦ Image neo4j:ubi9 [⣿⣶⣿⣷⠀⣿⣿] 133.2MB / 375.7MB Pulling                   11.7s
# [+] up 4/8
#  ⠧ Image neo4j:ubi9 [⣿⣶⣿⣿⠀⣿⣿] 135.3MB / 375.7MB Pulling                   11.8s
# [+] up 4/8
#  ⠇ Image neo4j:ubi9 [⣿⣶⣿⣿⠀⣿⣿] 136.3MB / 375.7MB Pulling                   11.9s
# [+] up 4/8
#  ⠏ Image neo4j:ubi9 [⣿⣶⣿⣿⠀⣿⣿] 139.5MB / 375.7MB Pulling                   12.0s
# [+] up 4/8
#  ⠋ Image neo4j:ubi9 [⣿⣶⣿⣿⠀⣿⣿] 141.6MB / 375.7MB Pulling                   12.1s
# [+] up 4/8
#  ⠙ Image neo4j:ubi9 [⣿⣶⣿⣿⠀⣿⣿] 143.7MB / 375.7MB Pulling                   12.2s
# [+] up 5/8
#  ⠹ Image neo4j:ubi9 [⣿⣶⣿⣿⠀⣿⣿] 145.8MB / 375.7MB Pulling                   12.3s
# [+] up 5/8
#  ⠸ Image neo4j:ubi9 [⣿⣶⣿⣿⠀⣿⣿] 148.9MB / 375.7MB Pulling                   12.4s
# [+] up 5/8
#  ⠼ Image neo4j:ubi9 [⣿⣶⣿⣿⠀⣿⣿]   151MB / 375.7MB Pulling                   12.5s
# [+] up 5/8
#  ⠴ Image neo4j:ubi9 [⣿⣶⣿⣿⡀⣿⣿] 153.1MB / 375.7MB Pulling                   12.6s
# [+] up 5/8
#  ⠦ Image neo4j:ubi9 [⣿⣷⣿⣿⡀⣿⣿] 155.2MB / 375.7MB Pulling                   12.7s
# [+] up 5/8
#  ⠧ Image neo4j:ubi9 [⣿⣷⣿⣿⡀⣿⣿] 158.3MB / 375.7MB Pulling                   12.8s
# [+] up 5/8
#  ⠇ Image neo4j:ubi9 [⣿⣷⣿⣿⡀⣿⣿] 161.5MB / 375.7MB Pulling                   12.9s
# [+] up 5/8
#  ⠏ Image neo4j:ubi9 [⣿⣷⣿⣿⡀⣿⣿] 162.5MB / 375.7MB Pulling                   13.0s
# [+] up 5/8
#  ⠋ Image neo4j:ubi9 [⣿⣷⣿⣿⡀⣿⣿] 165.7MB / 375.7MB Pulling                   13.1s
# [+] up 5/8
#  ⠙ Image neo4j:ubi9 [⣿⣷⣿⣿⡀⣿⣿] 167.8MB / 375.7MB Pulling                   13.2s
# [+] up 5/8
#  ⠹ Image neo4j:ubi9 [⣿⣷⣿⣿⡀⣿⣿] 170.9MB / 375.7MB Pulling                   13.3s
# [+] up 5/8
#  ⠸ Image neo4j:ubi9 [⣿⣷⣿⣿⡀⣿⣿] 174.1MB / 375.7MB Pulling                   13.4s
# [+] up 5/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿] 176.2MB / 375.7MB Pulling                   13.5s
# [+] up 5/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿] 178.3MB / 375.7MB Pulling                   13.6s
# [+] up 5/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿] 179.4MB / 375.7MB Pulling                   13.7s
# [+] up 5/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿] 181.5MB / 375.7MB Pulling                   13.8s
# [+] up 5/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿] 183.6MB / 375.7MB Pulling                   13.9s
# [+] up 5/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿] 185.7MB / 375.7MB Pulling                   14.0s
# [+] up 5/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿] 187.8MB / 375.7MB Pulling                   14.1s
# [+] up 5/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿] 189.9MB / 375.7MB Pulling                   14.2s
# [+] up 5/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⡀⣿⣿]   193MB / 375.7MB Pulling                   14.3s
# [+] up 5/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 195.1MB / 375.7MB Pulling                   14.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 197.2MB / 375.7MB Pulling                   14.5s
# [+] up 6/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 199.3MB / 375.7MB Pulling                   14.6s
# [+] up 6/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 201.4MB / 375.7MB Pulling                   14.7s
# [+] up 6/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 204.5MB / 375.7MB Pulling                   14.8s
# [+] up 6/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 206.6MB / 375.7MB Pulling                   14.9s
# [+] up 6/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 208.7MB / 375.7MB Pulling                   15.0s
# [+] up 6/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 211.9MB / 375.7MB Pulling                   15.1s
# [+] up 6/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿]   214MB / 375.7MB Pulling                   15.2s
# [+] up 6/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 216.1MB / 375.7MB Pulling                   15.3s
# [+] up 6/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 218.2MB / 375.7MB Pulling                   15.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 221.3MB / 375.7MB Pulling                   15.5s
# [+] up 6/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⣀⣿⣿] 223.4MB / 375.7MB Pulling                   15.6s
# [+] up 6/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 225.5MB / 375.7MB Pulling                   15.7s
# [+] up 6/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 228.7MB / 375.7MB Pulling                   15.8s
# [+] up 6/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 230.8MB / 375.7MB Pulling                   15.9s
# [+] up 6/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 232.8MB / 375.7MB Pulling                   16.0s
# [+] up 6/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 234.9MB / 375.7MB Pulling                   16.1s
# [+] up 6/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿]   237MB / 375.7MB Pulling                   16.2s
# [+] up 6/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 240.2MB / 375.7MB Pulling                   16.3s
# [+] up 6/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 242.3MB / 375.7MB Pulling                   16.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 244.4MB / 375.7MB Pulling                   16.5s
# [+] up 6/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 246.5MB / 375.7MB Pulling                   16.6s
# [+] up 6/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 249.6MB / 375.7MB Pulling                   16.7s
# [+] up 6/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⣄⣿⣿] 251.7MB / 375.7MB Pulling                   16.8s
# [+] up 6/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 253.8MB / 375.7MB Pulling                   16.9s
# [+] up 6/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 255.9MB / 375.7MB Pulling                   17.0s
# [+] up 6/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 259.1MB / 375.7MB Pulling                   17.1s
# [+] up 6/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 261.2MB / 375.7MB Pulling                   17.2s
# [+] up 6/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 263.3MB / 375.7MB Pulling                   17.3s
# [+] up 6/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 266.4MB / 375.7MB Pulling                   17.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 268.5MB / 375.7MB Pulling                   17.5s
# [+] up 6/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 270.6MB / 375.7MB Pulling                   17.6s
# [+] up 6/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 273.7MB / 375.7MB Pulling                   17.7s
# [+] up 6/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 275.8MB / 375.7MB Pulling                   17.8s
# [+] up 6/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 277.9MB / 375.7MB Pulling                   17.9s
# [+] up 6/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 281.1MB / 375.7MB Pulling                   18.0s
# [+] up 6/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⣤⣿⣿] 283.2MB / 375.7MB Pulling                   18.1s
# [+] up 6/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 286.3MB / 375.7MB Pulling                   18.2s
# [+] up 6/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 288.4MB / 375.7MB Pulling                   18.3s
# [+] up 6/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 290.5MB / 375.7MB Pulling                   18.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 292.6MB / 375.7MB Pulling                   18.5s
# [+] up 6/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 295.8MB / 375.7MB Pulling                   18.6s
# [+] up 6/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 297.9MB / 375.7MB Pulling                   18.7s
# [+] up 6/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 298.9MB / 375.7MB Pulling                   18.8s
# [+] up 6/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 302.1MB / 375.7MB Pulling                   18.9s
# [+] up 6/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 304.2MB / 375.7MB Pulling                   19.0s
# [+] up 6/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 306.2MB / 375.7MB Pulling                   19.1s
# [+] up 6/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 309.4MB / 375.7MB Pulling                   19.2s
# [+] up 6/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⣦⣿⣿] 311.5MB / 375.7MB Pulling                   19.3s
# [+] up 6/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 314.6MB / 375.7MB Pulling                   19.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 316.7MB / 375.7MB Pulling                   19.5s
# [+] up 6/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 318.8MB / 375.7MB Pulling                   19.6s
# [+] up 6/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 320.9MB / 375.7MB Pulling                   19.7s
# [+] up 6/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 324.1MB / 375.7MB Pulling                   19.8s
# [+] up 6/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 326.2MB / 375.7MB Pulling                   19.9s
# [+] up 6/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 328.3MB / 375.7MB Pulling                   20.0s
# [+] up 6/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 331.4MB / 375.7MB Pulling                   20.1s
# [+] up 6/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 333.5MB / 375.7MB Pulling                   20.2s
# [+] up 6/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 336.7MB / 375.7MB Pulling                   20.3s
# [+] up 6/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 338.8MB / 375.7MB Pulling                   20.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿] 340.9MB / 375.7MB Pulling                   20.5s
# [+] up 6/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⣶⣿⣿]   344MB / 375.7MB Pulling                   20.6s
# [+] up 6/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 346.1MB / 375.7MB Pulling                   20.7s
# [+] up 6/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 348.2MB / 375.7MB Pulling                   20.8s
# [+] up 6/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 351.3MB / 375.7MB Pulling                   20.9s
# [+] up 6/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 353.4MB / 375.7MB Pulling                   21.0s
# [+] up 6/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 355.5MB / 375.7MB Pulling                   21.1s
# [+] up 6/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 358.7MB / 375.7MB Pulling                   21.2s
# [+] up 6/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 360.8MB / 375.7MB Pulling                   21.3s
# [+] up 6/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 362.9MB / 375.7MB Pulling                   21.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿]   366MB / 375.7MB Pulling                   21.5s
# [+] up 6/8
#  ⠴ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 368.1MB / 375.7MB Pulling                   21.6s
# [+] up 6/8
#  ⠦ Image neo4j:ubi9 [⣿⣿⣿⣿⣷⣿⣿] 370.2MB / 375.7MB Pulling                   21.7s
# [+] up 6/8
#  ⠧ Image neo4j:ubi9 [⣿⣿⣿⣿⣿⣿⣿] 373.4MB / 375.7MB Pulling                   21.8s
# [+] up 6/8
#  ⠇ Image neo4j:ubi9 [⣿⣿⣿⣿⣿⣿⣿] 373.4MB / 375.7MB Pulling                   21.9s
# [+] up 6/8
#  ⠏ Image neo4j:ubi9 [⣿⣿⣿⣿⣿⣿⣿] 373.4MB / 375.7MB Pulling                   22.0s
# [+] up 6/8
#  ⠋ Image neo4j:ubi9 [⣿⣿⣿⣿⣿⣿⣿] 373.4MB / 375.7MB Pulling                   22.1s
# [+] up 6/8
#  ⠙ Image neo4j:ubi9 [⣿⣿⣿⣿⣿⣿⣿] 373.4MB / 375.7MB Pulling                   22.2s
# [+] up 6/8
#  ⠹ Image neo4j:ubi9 [⣿⣿⣿⣿⣿⣿⣿] 373.4MB / 375.7MB Pulling                   22.3s
# [+] up 6/8
#  ⠸ Image neo4j:ubi9 [⣿⣿⣿⣿⣿⣿⣿] 373.4MB / 375.7MB Pulling                   22.4s
# [+] up 6/8
#  ⠼ Image neo4j:ubi9 [⣿⣿⣿⣿⣿⣿⣿] 373.4MB / 375.7MB Pulling                   22.5s
# [+] up 8/9
#  ✔ Image neo4j:ubi9     Pulled                                            22.6s
#  ⠋ Container neo4j-instance Recreate                                       0.0s
# [+] up 8/9
#  ✔ Image neo4j:ubi9   Pulled                                              22.6s
#  ⠙ Container neo4j-instance Recreate                                       0.1s
# [+] up 8/9
#  ✔ Image neo4j:ubi9         Pulled                                        22.6s
#  ⠹ Container neo4j-instance Recreate                                       0.2s
# [+] up 8/9
#  ✔ Image neo4j:ubi9 Pulled                                                22.6s
#  ⠸ Container neo4j-instance Recreate                                       0.3s
# [+] up 8/9
#  ✔ Image neo4j:ubi9   Pulled                                              22.6s
#  ⠼ Container neo4j-instance Recreate                                       0.4s
# [+] up 9/9
#  ✔ Image neo4j:ubi9 Pulled                                                22.6s
#  ✔ Container neo4j-instance Recreated                                      0.4s
# [+] up 9/9
#  ✔ Image neo4j:ubi9   Pulled                                              22.6s
#  ✔ Container neo4j-instance Recreated                                      0.4s
# [+] up 8/9
#  ✔ Image neo4j:ubi9       Pulled                                          22.6s
#  ⠴ Container neo4j-instance Waiting                                        0.7s
# [+] up 8/9
#  ✔ Image neo4j:ubi9         Pulled                                        22.6s
#  ⠦ Container neo4j-instance Waiting                                        0.8s
# [+] up 8/9
#  ✔ Image neo4j:ubi9   Pulled                                              22.6s
#  ⠧ Container neo4j-instance Waiting                                        0.9s
# [+] up 8/9
#  ✔ Image neo4j:ubi9 Pulled                                                22.6s
#  ⠇ Container neo4j-instance Waiting                                        1.0s
# [+] up 8/9
#  ✔ Image neo4j:ubi9   Pulled                                              22.6s
#  ⠏ Container neo4j-instance Waiting                                        1.1s
# [+] up 9/9
#  ✔ Image neo4j:ubi9   Pulled                                              22.6s
#  ✔ Container neo4j-instance Healthy                                        1.1s
